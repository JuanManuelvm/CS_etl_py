# %%
import pandas as pd
from sqlalchemy import create_engine
import yaml

# %%
with open('C:/Users/WILSON/OneDrive/Escritorio/Septimo Semestre/CIENCIA DE DATOS/REPO_MONITOR/CS_etl_py/config.yml', 'r') as f:
    config = yaml.safe_load(f)
    config_co = config['CO_SA']
    
url_co = (f"{config_co['drivername']}://{config_co['user']}:{config_co['password']}@{config_co['host']}:{config_co['port']}/{config_co['dbname']}")

co_sa = create_engine(url_co)

# %%
def load_table(schema, table):
    query = f"SELECT * FROM {schema}.{table}"
    return pd.read_sql(query, co_sa)

# %%
salesorderheader = load_table("sales", "salesorderheader")
salesorderdetail = load_table("sales", "salesorderdetail")
customer = load_table("sales", "customer")
personcreditcard = load_table("sales", "personcreditcard")
salesperson = load_table("sales", "salesperson")
store = load_table("sales", "store")
specialoffer = load_table("sales", "specialoffer")
specialofferproduct = load_table("sales", "specialofferproduct")
salesterritory = load_table("sales", "salesterritory")
currency = load_table("sales", "currency")
currencyrate = load_table("sales", "currencyrate")

# %%
person = load_table("person", "person")
address = load_table("person", "address")
businessentity = load_table("person", "businessentity")
businessentityaddress = load_table("person", "businessentityaddress")
stateprovince = load_table("person", "stateprovince")
countryregion = load_table("person", "countryregion")

# %%
product = load_table("production", "product")
subcategory = load_table("production", "productsubcategory")
category = load_table("production", "productcategory")

# %%
employee = load_table("humanresources", "employee")
emp_history = load_table("humanresources", "employeedepartmenthistory")
department = load_table("humanresources", "department")

# %%
#DIMENCION DATOS
def build_dimdate(df, colname):
    date_df = pd.DataFrame()
    date_df["date"] = pd.to_datetime(df[colname].dropna().unique())

    date_df["datekey"] = date_df["date"].dt.strftime("%Y%m%d").astype(int)
    date_df["year"] = date_df["date"].dt.year
    date_df["month"] = date_df["date"].dt.month
    date_df["day"] = date_df["date"].dt.day
    date_df["quarter"] = date_df["date"].dt.quarter
    date_df["is_weekend"] = (date_df["date"].dt.weekday >= 5).astype(int)

    return date_df

dimdate_order = build_dimdate(salesorderheader, "orderdate")
dimdate_due = build_dimdate(salesorderheader, "duedate")
dimdate_ship = build_dimdate(salesorderheader, "shipdate")

# %%
currencyrate = currencyrate.rename(columns={'tocurrencycode': 'currencycode'})

# %%
#DIMENSION CURRENCY
dimcurrency = currency.merge(currencyrate, on="currencycode", how="left")

# %%
customer = customer.rename(columns={'personid': 'businessentityid'})
customer
# Out:
#        customerid  businessentityid  storeid  territoryid accountnumber  \
# 0               1               NaN    934.0            1    AW00000001
# 1               2               NaN   1028.0            1    AW00000002
# 2               3               NaN    642.0            4    AW00000003
# 3               4               NaN    932.0            4    AW00000004
# 4               5               NaN   1026.0            4    AW00000005
# ...           ...               ...      ...          ...           ...
# 19815       30114            1985.0   1986.0            7    AW00030114
# 19816       30115            1987.0   1988.0            6    AW00030115
# 19817       30116            1989.0   1990.0            4    AW00030116
# 19818       30117            1991.0   1992.0            4    AW00030117
# 19819       30118            1993.0   1994.0            3    AW00030118
#
#                                     rowguid                     modifieddate
# 0      3f5ae95e-b87d-4aed-95b4-c3797afcb74f 2014-09-12 11:15:07.263000+00:00
# 1      e552f657-a9af-4a7d-a645-c429d6e02491 2014-09-12 11:15:07.263000+00:00
# 2      130774b1-db21-4ef3-98c8-c104bcd6ed6d 2014-09-12 11:15:07.263000+00:00
# 3      ff862851-1daa-4044-be7c-3e85583c054d 2014-09-12 11:15:07.263000+00:00
# 4      83905bdc-6f5e-4f71-b162-c98da069f38a 2014-09-12 11:15:07.263000+00:00
# ...                                     ...                              ...
# 19815  97154f3d-28f1-4b15-ae03-9518b781ece3 2014-09-12 11:15:07.263000+00:00
# 19816  e4cf8fd5-30a4-4b8e-8fd8-47032e255778 2014-09-12 11:15:07.263000+00:00
# 19817  ec409609-d25d-41b8-9d15-a1aa6e89fc77 2014-09-12 11:15:07.263000+00:00
# 19818  6f08e2fb-1cd3-4f6e-a2e6-385669598b19 2014-09-12 11:15:07.263000+00:00
# 19819  2495b4eb-fe8b-459e-a1b6-dba25c04e626 2014-09-12 11:15:07.263000+00:00
#
# [19820 rows x 7 columns]

# %%
customer = customer.drop(columns=['rowguid', 'modifieddate','accountnumber'])
#customer = customer.drop(columns=['rowguid'])
customer
# Out:
#        customerid  businessentityid  storeid  territoryid
# 0               1               NaN    934.0            1
# 1               2               NaN   1028.0            1
# 2               3               NaN    642.0            4
# 3               4               NaN    932.0            4
# 4               5               NaN   1026.0            4
# ...           ...               ...      ...          ...
# 19815       30114            1985.0   1986.0            7
# 19816       30115            1987.0   1988.0            6
# 19817       30116            1989.0   1990.0            4
# 19818       30117            1991.0   1992.0            4
# 19819       30118            1993.0   1994.0            3
#
# [19820 rows x 4 columns]

# %%
internet_customers = customer[customer["storeid"].isna()]
cust = (
    internet_customers
    .merge(person, on="businessentityid", how="left")
)

# %%
cust
# Out:
#        customerid  businessentityid  storeid  territoryid persontype  \
# 0           11000           13531.0      NaN            9         IN
# 1           11001            5454.0      NaN            9         IN
# 2           11002           11269.0      NaN            9         IN
# 3           11003           11358.0      NaN            9         IN
# 4           11004           11901.0      NaN            9         IN
# ...           ...               ...      ...          ...        ...
# 18479       29479            4191.0      NaN            7         IN
# 18480       29480            4472.0      NaN           10         IN
# 18481       29481            8168.0      NaN            8         IN
# 18482       29482           12570.0      NaN            7         IN
# 18483       29483           18384.0      NaN            7         IN
#
#        namestyle title  firstname middlename lastname suffix  emailpromotion  \
# 0          False  None        Jon          V     Yang   None               1
# 1          False  None     Eugene          L    Huang   None               0
# 2          False  None      Ruben       None   Torres   None               2
# 3          False  None    Christy       None      Zhu   None               0
# 4          False  None  Elizabeth       None  Johnson   None               1
# ...          ...   ...        ...        ...      ...    ...             ...
# 18479      False  None      Tommy          L     Tang   None               2
# 18480      False  None       Nina          W     Raji   None               0
# 18481      False  None       Ivan       None     Suri   None               0
# 18482      False  None    Clayton       None    Zhang   None               1
# 18483      False  None      Jésus          L  Navarro   None               0
#
#       additionalcontactinfo  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ...                     ...
# 18479                  None
# 18480                  None
# 18481                  None
# 18482                  None
# 18483                  None
#
#                                             demographics  \
# 0      <IndividualSurvey xmlns="http://schemas.micros...
# 1      <IndividualSurvey xmlns="http://schemas.micros...
# 2      <IndividualSurvey xmlns="http://schemas.micros...
# 3      <IndividualSurvey xmlns="http://schemas.micros...
# 4      <IndividualSurvey xmlns="http://schemas.micros...
# ...                                                  ...
# 18479  <IndividualSurvey xmlns="http://schemas.micros...
# 18480  <IndividualSurvey xmlns="http://schemas.micros...
# 18481  <IndividualSurvey xmlns="http://schemas.micros...
# 18482  <IndividualSurvey xmlns="http://schemas.micros...
# 18483  <IndividualSurvey xmlns="http://schemas.micros...
#
#                                     rowguid              modifieddate
# 0      66416a79-00c0-4dee-bc3e-662a3d8f6424 2011-06-21 00:00:00+00:00
# 1      82482f35-0f48-44e1-8a73-c11518b5a979 2011-06-17 00:00:00+00:00
# 2      ceb6b318-5d42-4e4f-9646-aa406758000e 2011-06-09 00:00:00+00:00
# 3      334c9ee5-03d3-4774-a886-5ec7ba93f034 2011-05-31 00:00:00+00:00
# 4      8609c9c5-f804-4de8-bb5b-9344971bd670 2011-06-25 00:00:00+00:00
# ...                                     ...                       ...
# 18479  0acfc8d3-5415-4b2b-b5d3-214a21cf32e5 2013-02-04 00:00:00+00:00
# 18480  3f4e9c34-35da-4483-b92d-e3bf98990a03 2013-12-17 00:00:00+00:00
# 18481  73cbf939-43c4-47ac-a025-bc3e7e3980df 2012-01-13 00:00:00+00:00
# 18482  18eae52a-121b-40b9-895e-64150fa677f1 2013-02-18 00:00:00+00:00
# 18483  3d7f8bd7-d71f-4304-94e2-4d9d548e64db 2013-02-09 00:00:00+00:00
#
# [18484 rows x 16 columns]

# %%
#customer = customer[['customerid', 'businessentityid']]
#person = person[['businessentityid', 'firstname', 'lastname']]
# Customer → Person
#cust = customer.merge(person, on='businessentityid', how='left')
cust
# Out:
#        customerid  businessentityid  storeid  territoryid persontype  \
# 0           11000           13531.0      NaN            9         IN
# 1           11001            5454.0      NaN            9         IN
# 2           11002           11269.0      NaN            9         IN
# 3           11003           11358.0      NaN            9         IN
# 4           11004           11901.0      NaN            9         IN
# ...           ...               ...      ...          ...        ...
# 18479       29479            4191.0      NaN            7         IN
# 18480       29480            4472.0      NaN           10         IN
# 18481       29481            8168.0      NaN            8         IN
# 18482       29482           12570.0      NaN            7         IN
# 18483       29483           18384.0      NaN            7         IN
#
#        namestyle title  firstname middlename lastname suffix  emailpromotion  \
# 0          False  None        Jon          V     Yang   None               1
# 1          False  None     Eugene          L    Huang   None               0
# 2          False  None      Ruben       None   Torres   None               2
# 3          False  None    Christy       None      Zhu   None               0
# 4          False  None  Elizabeth       None  Johnson   None               1
# ...          ...   ...        ...        ...      ...    ...             ...
# 18479      False  None      Tommy          L     Tang   None               2
# 18480      False  None       Nina          W     Raji   None               0
# 18481      False  None       Ivan       None     Suri   None               0
# 18482      False  None    Clayton       None    Zhang   None               1
# 18483      False  None      Jésus          L  Navarro   None               0
#
#       additionalcontactinfo  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ...                     ...
# 18479                  None
# 18480                  None
# 18481                  None
# 18482                  None
# 18483                  None
#
#                                             demographics  \
# 0      <IndividualSurvey xmlns="http://schemas.micros...
# 1      <IndividualSurvey xmlns="http://schemas.micros...
# 2      <IndividualSurvey xmlns="http://schemas.micros...
# 3      <IndividualSurvey xmlns="http://schemas.micros...
# 4      <IndividualSurvey xmlns="http://schemas.micros...
# ...                                                  ...
# 18479  <IndividualSurvey xmlns="http://schemas.micros...
# 18480  <IndividualSurvey xmlns="http://schemas.micros...
# 18481  <IndividualSurvey xmlns="http://schemas.micros...
# 18482  <IndividualSurvey xmlns="http://schemas.micros...
# 18483  <IndividualSurvey xmlns="http://schemas.micros...
#
#                                     rowguid              modifieddate
# 0      66416a79-00c0-4dee-bc3e-662a3d8f6424 2011-06-21 00:00:00+00:00
# 1      82482f35-0f48-44e1-8a73-c11518b5a979 2011-06-17 00:00:00+00:00
# 2      ceb6b318-5d42-4e4f-9646-aa406758000e 2011-06-09 00:00:00+00:00
# 3      334c9ee5-03d3-4774-a886-5ec7ba93f034 2011-05-31 00:00:00+00:00
# 4      8609c9c5-f804-4de8-bb5b-9344971bd670 2011-06-25 00:00:00+00:00
# ...                                     ...                       ...
# 18479  0acfc8d3-5415-4b2b-b5d3-214a21cf32e5 2013-02-04 00:00:00+00:00
# 18480  3f4e9c34-35da-4483-b92d-e3bf98990a03 2013-12-17 00:00:00+00:00
# 18481  73cbf939-43c4-47ac-a025-bc3e7e3980df 2012-01-13 00:00:00+00:00
# 18482  18eae52a-121b-40b9-895e-64150fa677f1 2013-02-18 00:00:00+00:00
# 18483  3d7f8bd7-d71f-4304-94e2-4d9d548e64db 2013-02-09 00:00:00+00:00
#
# [18484 rows x 16 columns]

# %%
cust = cust.rename(columns={"territoryid": "territoryidCustomer"})

# %%
cust = cust[['customerid','businessentityid','territoryidCustomer','firstname','lastname']]
cust
# Out:
#        customerid  businessentityid  territoryidCustomer  firstname lastname
# 0           11000           13531.0                    9        Jon     Yang
# 1           11001            5454.0                    9     Eugene    Huang
# 2           11002           11269.0                    9      Ruben   Torres
# 3           11003           11358.0                    9    Christy      Zhu
# 4           11004           11901.0                    9  Elizabeth  Johnson
# ...           ...               ...                  ...        ...      ...
# 18479       29479            4191.0                    7      Tommy     Tang
# 18480       29480            4472.0                   10       Nina     Raji
# 18481       29481            8168.0                    8       Ivan     Suri
# 18482       29482           12570.0                    7    Clayton    Zhang
# 18483       29483           18384.0                    7      Jésus  Navarro
#
# [18484 rows x 5 columns]

# %%
businessentityaddress = businessentityaddress[['businessentityid', 'addressid']]
address = address[['addressid','addressline1', 'stateprovinceid', 'city']]
stateprovince = stateprovince[['stateprovinceid','countryregioncode', 'territoryid']]

# %%
# Address
cust = cust.merge(businessentityaddress, on="businessentityid", how="left")

# %%
#cust = cust.drop(columns=["addressid_x"])
#cust = cust.rename(columns={"addressid_y": "addressid"})
cust = cust[['customerid','businessentityid','firstname','lastname','addressid']]
cust
# Out:
#        customerid  businessentityid  firstname lastname  addressid
# 0           11000           13531.0        Jon     Yang      22601
# 1           11001            5454.0     Eugene    Huang      14489
# 2           11002           11269.0      Ruben   Torres      20336
# 3           11003           11358.0    Christy      Zhu      20425
# 4           11004           11901.0  Elizabeth  Johnson      20971
# ...           ...               ...        ...      ...        ...
# 18503       29479            4191.0      Tommy     Tang      13226
# 18504       29480            4472.0       Nina     Raji      13507
# 18505       29481            8168.0       Ivan     Suri      17218
# 18506       29482           12570.0    Clayton    Zhang      21640
# 18507       29483           18384.0      Jésus  Navarro      27472
#
# [18508 rows x 5 columns]

# %%
cust = cust.merge(address, on="addressid", how="left")
cust
# Out:
#        customerid  businessentityid  firstname lastname  addressid  \
# 0           11000           13531.0        Jon     Yang      22601
# 1           11001            5454.0     Eugene    Huang      14489
# 2           11002           11269.0      Ruben   Torres      20336
# 3           11003           11358.0    Christy      Zhu      20425
# 4           11004           11901.0  Elizabeth  Johnson      20971
# ...           ...               ...        ...      ...        ...
# 18503       29479            4191.0      Tommy     Tang      13226
# 18504       29480            4472.0       Nina     Raji      13507
# 18505       29481            8168.0       Ivan     Suri      17218
# 18506       29482           12570.0    Clayton    Zhang      21640
# 18507       29483           18384.0      Jésus  Navarro      27472
#
#                     addressline1  stateprovinceid              city
# 0                3761 N. 14th St               64       Rockhampton
# 1                     2243 W St.               77           Seaford
# 2               5844 Linden Land               71            Hobart
# 3               1825 Village Pl.               50        North Ryde
# 4            7553 Harness Circle               50        Wollongong
# ...                          ...              ...               ...
# 18503          111, rue Maillard              164        Versailles
# 18504          9 Katherine Drive               14            London
# 18505                Knaackstr 4                8               Hof
# 18506     1080, quai de Grenelle              103        Saint Ouen
# 18507  244, rue de la Centenaire              178  Paris La Defense
#
# [18508 rows x 8 columns]

# %%
cust = cust.merge(stateprovince, on="stateprovinceid", how="left")
cust
# Out:
#        customerid  businessentityid  firstname lastname  addressid  \
# 0           11000           13531.0        Jon     Yang      22601
# 1           11001            5454.0     Eugene    Huang      14489
# 2           11002           11269.0      Ruben   Torres      20336
# 3           11003           11358.0    Christy      Zhu      20425
# 4           11004           11901.0  Elizabeth  Johnson      20971
# ...           ...               ...        ...      ...        ...
# 18503       29479            4191.0      Tommy     Tang      13226
# 18504       29480            4472.0       Nina     Raji      13507
# 18505       29481            8168.0       Ivan     Suri      17218
# 18506       29482           12570.0    Clayton    Zhang      21640
# 18507       29483           18384.0      Jésus  Navarro      27472
#
#                     addressline1  stateprovinceid              city  \
# 0                3761 N. 14th St               64       Rockhampton
# 1                     2243 W St.               77           Seaford
# 2               5844 Linden Land               71            Hobart
# 3               1825 Village Pl.               50        North Ryde
# 4            7553 Harness Circle               50        Wollongong
# ...                          ...              ...               ...
# 18503          111, rue Maillard              164        Versailles
# 18504          9 Katherine Drive               14            London
# 18505                Knaackstr 4                8               Hof
# 18506     1080, quai de Grenelle              103        Saint Ouen
# 18507  244, rue de la Centenaire              178  Paris La Defense
#
#       countryregioncode  territoryid
# 0                    AU            9
# 1                    AU            9
# 2                    AU            9
# 3                    AU            9
# 4                    AU            9
# ...                 ...          ...
# 18503                FR            7
# 18504                GB           10
# 18505                DE            8
# 18506                FR            7
# 18507                FR            7
#
# [18508 rows x 10 columns]

# %%
#cust = cust.drop(columns=["countryregioncode_x"])
#cust = cust.rename(columns={"countryregioncode_y": "countryregioncode"})
#cust = cust.drop(columns=["territoryid_x"])
#cust = cust.rename(columns={"territoryid_y": "territoryid"})

#DIMENCION CUSTOMER SOLO VENTAS POR INTERNET
dimcustomer = cust[[
    "customerid",
    "firstname",
    "lastname",
    "addressline1",
    "city",
    "stateprovinceid",
    "countryregioncode",
    "territoryid"
]].drop_duplicates()

cust
# Out:
#        customerid  businessentityid  firstname lastname  addressid  \
# 0           11000           13531.0        Jon     Yang      22601
# 1           11001            5454.0     Eugene    Huang      14489
# 2           11002           11269.0      Ruben   Torres      20336
# 3           11003           11358.0    Christy      Zhu      20425
# 4           11004           11901.0  Elizabeth  Johnson      20971
# ...           ...               ...        ...      ...        ...
# 18503       29479            4191.0      Tommy     Tang      13226
# 18504       29480            4472.0       Nina     Raji      13507
# 18505       29481            8168.0       Ivan     Suri      17218
# 18506       29482           12570.0    Clayton    Zhang      21640
# 18507       29483           18384.0      Jésus  Navarro      27472
#
#                     addressline1  stateprovinceid              city  \
# 0                3761 N. 14th St               64       Rockhampton
# 1                     2243 W St.               77           Seaford
# 2               5844 Linden Land               71            Hobart
# 3               1825 Village Pl.               50        North Ryde
# 4            7553 Harness Circle               50        Wollongong
# ...                          ...              ...               ...
# 18503          111, rue Maillard              164        Versailles
# 18504          9 Katherine Drive               14            London
# 18505                Knaackstr 4                8               Hof
# 18506     1080, quai de Grenelle              103        Saint Ouen
# 18507  244, rue de la Centenaire              178  Paris La Defense
#
#       countryregioncode  territoryid
# 0                    AU            9
# 1                    AU            9
# 2                    AU            9
# 3                    AU            9
# 4                    AU            9
# ...                 ...          ...
# 18503                FR            7
# 18504                GB           10
# 18505                DE            8
# 18506                FR            7
# 18507                FR            7
#
# [18508 rows x 10 columns]

# %%
#---------DIMENSION REVENDEDORES

reseller = customer[customer["storeid"].notnull()]
storeRevendedoreid = store
storeRevendedoreid = storeRevendedoreid.rename(columns={'businessentityid':'storeid'})
reseller = reseller.merge(storeRevendedoreid, on="storeid", how="left")

# %%
dimreseller = reseller[[
    "customerid",
    "storeid",
    "name",
    "businessentityid"
]].drop_duplicates()
dimreseller
# Out:
#       customerid  storeid                           name  businessentityid
# 0              1    934.0                   A Bike Store               NaN
# 1              2   1028.0             Progressive Sports               NaN
# 2              3    642.0       Advanced Bike Components               NaN
# 3              4    932.0          Modular Cycle Systems               NaN
# 4              5   1026.0     Metropolitan Sports Supply               NaN
# ...          ...      ...                            ...               ...
# 1331       30114   1986.0           Recreation Toy Store            1985.0
# 1332       30115   1988.0                    Retreat Inn            1987.0
# 1333       30116   1990.0  Technical Parts Manufacturing            1989.0
# 1334       30117   1992.0        Totes & Baskets Company            1991.0
# 1335       30118   1994.0                 World of Bikes            1993.0
#
# [1336 rows x 4 columns]

# %%
#DIMENSION EMPLEADO

# %%
employeeMerge = employee.drop(columns={'rowguid','modifieddate'})
dimemployee = employeeMerge.merge(emp_history, on="businessentityid", how="left")
dimemployee = dimemployee.drop(columns={'modifieddate'})
dimemployee
# Out:
#      businessentityid nationalidnumber                   loginid  \
# 0                   1        295847284      adventure-works\ken0
# 1                   2        245797967    adventure-works\terri0
# 2                   3        509647174  adventure-works\roberto0
# 3                   4        112457891      adventure-works\rob0
# 4                   4        112457891      adventure-works\rob0
# ..                ...              ...                       ...
# 291               286        758596752     adventure-works\lynn0
# 292               287        982310417      adventure-works\amy0
# 293               288        954276278   adventure-works\rachel0
# 294               289        668991357      adventure-works\jae0
# 295               290        134219713   adventure-works\ranjit0
#
#        organizationnode  organizationlevel                       jobtitle  \
# 0                  None                NaN        Chief Executive Officer
# 1                [b'X']                1.0  Vice President of Engineering
# 2       [b'Z', b'\xc0']                2.0            Engineering Manager
# 3       [b'Z', b'\xd6']                3.0           Senior Tool Designer
# 4       [b'Z', b'\xd6']                3.0           Senior Tool Designer
# ..                  ...                ...                            ...
# 291  [b'\x95', b'\xab']                3.0           Sales Representative
# 292  [b'\x95', b'\xe0']                2.0         European Sales Manager
# 293  [b'\x95', b'\xeb']                3.0           Sales Representative
# 294  [b'\x95', b'\xed']                3.0           Sales Representative
# 295  [b'\x95', b'\xef']                3.0           Sales Representative
#
#       birthdate maritalstatus gender    hiredate  salariedflag  vacationhours  \
# 0    1969-01-29             S      M  2009-01-14          True             99
# 1    1971-08-01             S      F  2008-01-31          True              1
# 2    1974-11-12             M      M  2007-11-11          True              2
# 3    1974-12-23             S      M  2007-12-05         False             48
# 4    1974-12-23             S      M  2007-12-05         False             48
# ..          ...           ...    ...         ...           ...            ...
# 291  1977-02-14             S      F  2013-05-30          True             36
# 292  1957-09-20             M      F  2012-04-16          True             21
# 293  1975-07-09             S      F  2013-05-30          True             35
# 294  1968-03-17             M      F  2012-05-30          True             37
# 295  1975-09-30             S      M  2012-05-30          True             34
#
#      sickleavehours  currentflag  departmentid  shiftid   startdate  \
# 0                69         True            16        1  2009-01-14
# 1                20         True             1        1  2008-01-31
# 2                21         True             1        1  2007-11-11
# 3                80         True             1        1  2007-12-05
# 4                80         True             2        1  2010-05-31
# ..              ...          ...           ...      ...         ...
# 291              38         True             3        1  2013-05-30
# 292              30         True             3        1  2012-04-16
# 293              37         True             3        1  2013-05-30
# 294              38         True             3        1  2012-05-30
# 295              37         True             3        1  2012-05-30
#
#         enddate
# 0          None
# 1          None
# 2          None
# 3    2010-05-30
# 4          None
# ..          ...
# 291        None
# 292        None
# 293        None
# 294        None
# 295        None
#
# [296 rows x 18 columns]

# %%
#departmentMerge = department.drop(columns={'modifieddate'})
#dimemployee.merge(departmentMerge, on="departmentid", how="left")
dimemployee = dimemployee[['businessentityid','jobtitle', 'loginid', 'departmentid' ]]
dimemployee
# Out:
#      businessentityid                       jobtitle  \
# 0                   1        Chief Executive Officer
# 1                   2  Vice President of Engineering
# 2                   3            Engineering Manager
# 3                   4           Senior Tool Designer
# 4                   4           Senior Tool Designer
# ..                ...                            ...
# 291               286           Sales Representative
# 292               287         European Sales Manager
# 293               288           Sales Representative
# 294               289           Sales Representative
# 295               290           Sales Representative
#
#                       loginid  departmentid
# 0        adventure-works\ken0            16
# 1      adventure-works\terri0             1
# 2    adventure-works\roberto0             1
# 3        adventure-works\rob0             1
# 4        adventure-works\rob0             2
# ..                        ...           ...
# 291     adventure-works\lynn0             3
# 292      adventure-works\amy0             3
# 293   adventure-works\rachel0             3
# 294      adventure-works\jae0             3
# 295   adventure-works\ranjit0             3
#
# [296 rows x 4 columns]

# %%
department
# Out:
#     departmentid                        name  \
# 0              1                 Engineering
# 1              2                 Tool Design
# 2              3                       Sales
# 3              4                   Marketing
# 4              5                  Purchasing
# 5              6    Research and Development
# 6              7                  Production
# 7              8          Production Control
# 8              9             Human Resources
# 9             10                     Finance
# 10            11        Information Services
# 11            12            Document Control
# 12            13           Quality Assurance
# 13            14  Facilities and Maintenance
# 14            15      Shipping and Receiving
# 15            16                   Executive
#
#                                groupname              modifieddate
# 0               Research and Development 2008-04-30 00:00:00+00:00
# 1               Research and Development 2008-04-30 00:00:00+00:00
# 2                    Sales and Marketing 2008-04-30 00:00:00+00:00
# 3                    Sales and Marketing 2008-04-30 00:00:00+00:00
# 4                   Inventory Management 2008-04-30 00:00:00+00:00
# 5               Research and Development 2008-04-30 00:00:00+00:00
# 6                          Manufacturing 2008-04-30 00:00:00+00:00
# 7                          Manufacturing 2008-04-30 00:00:00+00:00
# 8   Executive General and Administration 2008-04-30 00:00:00+00:00
# 9   Executive General and Administration 2008-04-30 00:00:00+00:00
# 10  Executive General and Administration 2008-04-30 00:00:00+00:00
# 11                     Quality Assurance 2008-04-30 00:00:00+00:00
# 12                     Quality Assurance 2008-04-30 00:00:00+00:00
# 13  Executive General and Administration 2008-04-30 00:00:00+00:00
# 14                  Inventory Management 2008-04-30 00:00:00+00:00
# 15  Executive General and Administration 2008-04-30 00:00:00+00:00

# %%
departmentMerge = department
departmentMerge = departmentMerge[['departmentid', 'name', 'groupname']]
dimemployee = dimemployee.merge(departmentMerge, on="departmentid", how="left")
dimemployee
# Out:
#      businessentityid                       jobtitle  \
# 0                   1        Chief Executive Officer
# 1                   2  Vice President of Engineering
# 2                   3            Engineering Manager
# 3                   4           Senior Tool Designer
# 4                   4           Senior Tool Designer
# ..                ...                            ...
# 291               286           Sales Representative
# 292               287         European Sales Manager
# 293               288           Sales Representative
# 294               289           Sales Representative
# 295               290           Sales Representative
#
#                       loginid  departmentid         name  \
# 0        adventure-works\ken0            16    Executive
# 1      adventure-works\terri0             1  Engineering
# 2    adventure-works\roberto0             1  Engineering
# 3        adventure-works\rob0             1  Engineering
# 4        adventure-works\rob0             2  Tool Design
# ..                        ...           ...          ...
# 291     adventure-works\lynn0             3        Sales
# 292      adventure-works\amy0             3        Sales
# 293   adventure-works\rachel0             3        Sales
# 294      adventure-works\jae0             3        Sales
# 295   adventure-works\ranjit0             3        Sales
#
#                                 groupname
# 0    Executive General and Administration
# 1                Research and Development
# 2                Research and Development
# 3                Research and Development
# 4                Research and Development
# ..                                    ...
# 291                   Sales and Marketing
# 292                   Sales and Marketing
# 293                   Sales and Marketing
# 294                   Sales and Marketing
# 295                   Sales and Marketing
#
# [296 rows x 6 columns]

# %%
dimemployee
# Out:
#      businessentityid                       jobtitle  \
# 0                   1        Chief Executive Officer
# 1                   2  Vice President of Engineering
# 2                   3            Engineering Manager
# 3                   4           Senior Tool Designer
# 4                   4           Senior Tool Designer
# ..                ...                            ...
# 291               286           Sales Representative
# 292               287         European Sales Manager
# 293               288           Sales Representative
# 294               289           Sales Representative
# 295               290           Sales Representative
#
#                       loginid  departmentid         name  \
# 0        adventure-works\ken0            16    Executive
# 1      adventure-works\terri0             1  Engineering
# 2    adventure-works\roberto0             1  Engineering
# 3        adventure-works\rob0             1  Engineering
# 4        adventure-works\rob0             2  Tool Design
# ..                        ...           ...          ...
# 291     adventure-works\lynn0             3        Sales
# 292      adventure-works\amy0             3        Sales
# 293   adventure-works\rachel0             3        Sales
# 294      adventure-works\jae0             3        Sales
# 295   adventure-works\ranjit0             3        Sales
#
#                                 groupname
# 0    Executive General and Administration
# 1                Research and Development
# 2                Research and Development
# 3                Research and Development
# 4                Research and Development
# ..                                    ...
# 291                   Sales and Marketing
# 292                   Sales and Marketing
# 293                   Sales and Marketing
# 294                   Sales and Marketing
# 295                   Sales and Marketing
#
# [296 rows x 6 columns]

# %%
salespersonMerge = salesperson
personMerge = person
salespersonMerge = salespersonMerge[['businessentityid','territoryid']]
personMerge = personMerge[['businessentityid','firstname','lastname']]
#dimemployee = dimemployee.merge(salespersonMerge, on="businessentityid", how="left")

# %%
dimemployee = dimemployee.merge(salespersonMerge, on="businessentityid", how="left")

# %%
dimemployee = dimemployee.merge(personMerge, on="businessentityid", how="left")

# %%
dimemployee = dimemployee.rename(columns={"businessentityid": "employeekey",'name':'departmentname'})

# %%
#DIMENCION EMPLADO COMPLETA
dimemployee
# Out:
#      employeekey                       jobtitle                   loginid  \
# 0              1        Chief Executive Officer      adventure-works\ken0
# 1              2  Vice President of Engineering    adventure-works\terri0
# 2              3            Engineering Manager  adventure-works\roberto0
# 3              4           Senior Tool Designer      adventure-works\rob0
# 4              4           Senior Tool Designer      adventure-works\rob0
# ..           ...                            ...                       ...
# 291          286           Sales Representative     adventure-works\lynn0
# 292          287         European Sales Manager      adventure-works\amy0
# 293          288           Sales Representative   adventure-works\rachel0
# 294          289           Sales Representative      adventure-works\jae0
# 295          290           Sales Representative   adventure-works\ranjit0
#
#      departmentid departmentname                             groupname  \
# 0              16      Executive  Executive General and Administration
# 1               1    Engineering              Research and Development
# 2               1    Engineering              Research and Development
# 3               1    Engineering              Research and Development
# 4               2    Tool Design              Research and Development
# ..            ...            ...                                   ...
# 291             3          Sales                   Sales and Marketing
# 292             3          Sales                   Sales and Marketing
# 293             3          Sales                   Sales and Marketing
# 294             3          Sales                   Sales and Marketing
# 295             3          Sales                   Sales and Marketing
#
#      territoryid firstname           lastname
# 0            NaN       Ken            Sánchez
# 1            NaN     Terri              Duffy
# 2            NaN   Roberto         Tamburello
# 3            NaN       Rob            Walters
# 4            NaN       Rob            Walters
# ..           ...       ...                ...
# 291          9.0      Lynn           Tsoflias
# 292          NaN       Amy            Alberts
# 293          8.0    Rachel             Valdez
# 294         10.0       Jae                Pak
# 295          7.0    Ranjit  Varkey Chudukatil
#
# [296 rows x 9 columns]

# %%
#dimencion producto
dimproduct = product[['productsubcategoryid','name','color', 'size','listprice']]
subcategoryMerge = subcategory.rename(columns={'name':'productsubcategoryname'})
dimproduct = product.merge(subcategoryMerge, on = "productsubcategoryid", how="left")
dimproduct
# Out:
#      productid                   name productnumber  makeflag  \
# 0            1        Adjustable Race       AR-5381     False
# 1            2           Bearing Ball       BA-8327     False
# 2            3        BB Ball Bearing       BE-2349      True
# 3            4  Headset Ball Bearings       BE-2908     False
# 4          316                  Blade       BL-2036      True
# ..         ...                    ...           ...       ...
# 499        995      ML Bottom Bracket       BB-8107      True
# 500        996      HL Bottom Bracket       BB-9108      True
# 501        997     Road-750 Black, 44    BK-R19B-44      True
# 502        998     Road-750 Black, 48    BK-R19B-48      True
# 503        999     Road-750 Black, 52    BK-R19B-52      True
#
#      finishedgoodsflag  color  safetystocklevel  reorderpoint  standardcost  \
# 0                False   None              1000           750        0.0000
# 1                False   None              1000           750        0.0000
# 2                False   None               800           600        0.0000
# 3                False   None               800           600        0.0000
# 4                False   None               800           600        0.0000
# ..                 ...    ...               ...           ...           ...
# 499               True   None               500           375       44.9506
# 500               True   None               500           375       53.9416
# 501               True  Black               100            75      343.6496
# 502               True  Black               100            75      343.6496
# 503               True  Black               100            75      343.6496
#
#      listprice  ... productmodelid             sellstartdate sellenddate  \
# 0         0.00  ...            NaN 2008-04-30 00:00:00+00:00         NaT
# 1         0.00  ...            NaN 2008-04-30 00:00:00+00:00         NaT
# 2         0.00  ...            NaN 2008-04-30 00:00:00+00:00         NaT
# 3         0.00  ...            NaN 2008-04-30 00:00:00+00:00         NaT
# 4         0.00  ...            NaN 2008-04-30 00:00:00+00:00         NaT
# ..         ...  ...            ...                       ...         ...
# 499     101.24  ...           96.0 2013-05-30 00:00:00+00:00         NaT
# 500     121.49  ...           97.0 2013-05-30 00:00:00+00:00         NaT
# 501     539.99  ...           31.0 2013-05-30 00:00:00+00:00         NaT
# 502     539.99  ...           31.0 2013-05-30 00:00:00+00:00         NaT
# 503     539.99  ...           31.0 2013-05-30 00:00:00+00:00         NaT
#
#      discontinueddate                             rowguid_x  \
# 0                None  694215b7-08f7-4c0d-acb1-d734ba44c0c8
# 1                None  58ae3c20-4f3a-4749-a7d4-d568806cc537
# 2                None  9c21aed2-5bfa-4f18-bcb8-f11638dc2e4e
# 3                None  ecfed6cb-51ff-49b5-b06c-7d8ac834db8b
# 4                None  e73e9750-603b-4131-89f5-3dd15ed5ff80
# ..                ...                                   ...
# 499              None  71ab847f-d091-42d6-b735-7b0c2d82fc84
# 500              None  230c47c5-08b2-4ce3-b706-69c0bdd62965
# 501              None  44ce4802-409f-43ab-9b27-ca53421805be
# 502              None  3de9a212-1d49-40b6-b10a-f564d981dbde
# 503              None  ae638923-2b67-4679-b90e-abbab17dca31
#
#                       modifieddate_x productcategoryid productsubcategoryname  \
# 0   2014-02-08 10:01:36.827000+00:00               NaN                    NaN
# 1   2014-02-08 10:01:36.827000+00:00               NaN                    NaN
# 2   2014-02-08 10:01:36.827000+00:00               NaN                    NaN
# 3   2014-02-08 10:01:36.827000+00:00               NaN                    NaN
# 4   2014-02-08 10:01:36.827000+00:00               NaN                    NaN
# ..                               ...               ...                    ...
# 499 2014-02-08 10:01:36.827000+00:00               2.0        Bottom Brackets
# 500 2014-02-08 10:01:36.827000+00:00               2.0        Bottom Brackets
# 501 2014-02-08 10:01:36.827000+00:00               1.0             Road Bikes
# 502 2014-02-08 10:01:36.827000+00:00               1.0             Road Bikes
# 503 2014-02-08 10:01:36.827000+00:00               1.0             Road Bikes
#
#                                 rowguid_y            modifieddate_y
# 0                                     NaN                       NaT
# 1                                     NaN                       NaT
# 2                                     NaN                       NaT
# 3                                     NaN                       NaT
# 4                                     NaN                       NaT
# ..                                    ...                       ...
# 499  a9e54089-8a1e-4cf5-8646-e3801f685934 2008-04-30 00:00:00+00:00
# 500  a9e54089-8a1e-4cf5-8646-e3801f685934 2008-04-30 00:00:00+00:00
# 501  000310c0-bcc8-42c4-b0c3-45ae611af06b 2008-04-30 00:00:00+00:00
# 502  000310c0-bcc8-42c4-b0c3-45ae611af06b 2008-04-30 00:00:00+00:00
# 503  000310c0-bcc8-42c4-b0c3-45ae611af06b 2008-04-30 00:00:00+00:00
#
# [504 rows x 29 columns]

# %%
categoryMerge = category.rename(columns={'name':'productcategoryname'})
dimproduct = dimproduct.merge(categoryMerge, on="productcategoryid", how="left")
# Out:
#      productid                   name productnumber  makeflag  \
# 0            1        Adjustable Race       AR-5381     False
# 1            2           Bearing Ball       BA-8327     False
# 2            3        BB Ball Bearing       BE-2349      True
# 3            4  Headset Ball Bearings       BE-2908     False
# 4          316                  Blade       BL-2036      True
# ..         ...                    ...           ...       ...
# 499        995      ML Bottom Bracket       BB-8107      True
# 500        996      HL Bottom Bracket       BB-9108      True
# 501        997     Road-750 Black, 44    BK-R19B-44      True
# 502        998     Road-750 Black, 48    BK-R19B-48      True
# 503        999     Road-750 Black, 52    BK-R19B-52      True
#
#      finishedgoodsflag  color  safetystocklevel  reorderpoint  standardcost  \
# 0                False   None              1000           750        0.0000
# 1                False   None              1000           750        0.0000
# 2                False   None               800           600        0.0000
# 3                False   None               800           600        0.0000
# 4                False   None               800           600        0.0000
# ..                 ...    ...               ...           ...           ...
# 499               True   None               500           375       44.9506
# 500               True   None               500           375       53.9416
# 501               True  Black               100            75      343.6496
# 502               True  Black               100            75      343.6496
# 503               True  Black               100            75      343.6496
#
#      listprice  ... discontinueddate                             rowguid_x  \
# 0         0.00  ...             None  694215b7-08f7-4c0d-acb1-d734ba44c0c8
# 1         0.00  ...             None  58ae3c20-4f3a-4749-a7d4-d568806cc537
# 2         0.00  ...             None  9c21aed2-5bfa-4f18-bcb8-f11638dc2e4e
# 3         0.00  ...             None  ecfed6cb-51ff-49b5-b06c-7d8ac834db8b
# 4         0.00  ...             None  e73e9750-603b-4131-89f5-3dd15ed5ff80
# ..         ...  ...              ...                                   ...
# 499     101.24  ...             None  71ab847f-d091-42d6-b735-7b0c2d82fc84
# 500     121.49  ...             None  230c47c5-08b2-4ce3-b706-69c0bdd62965
# 501     539.99  ...             None  44ce4802-409f-43ab-9b27-ca53421805be
# 502     539.99  ...             None  3de9a212-1d49-40b6-b10a-f564d981dbde
# 503     539.99  ...             None  ae638923-2b67-4679-b90e-abbab17dca31
#
#                       modifieddate_x  productcategoryid  \
# 0   2014-02-08 10:01:36.827000+00:00                NaN
# 1   2014-02-08 10:01:36.827000+00:00                NaN
# 2   2014-02-08 10:01:36.827000+00:00                NaN
# 3   2014-02-08 10:01:36.827000+00:00                NaN
# 4   2014-02-08 10:01:36.827000+00:00                NaN
# ..                               ...                ...
# 499 2014-02-08 10:01:36.827000+00:00                2.0
# 500 2014-02-08 10:01:36.827000+00:00                2.0
# 501 2014-02-08 10:01:36.827000+00:00                1.0
# 502 2014-02-08 10:01:36.827000+00:00                1.0
# 503 2014-02-08 10:01:36.827000+00:00                1.0
#
#      productsubcategoryname                             rowguid_y  \
# 0                       NaN                                   NaN
# 1                       NaN                                   NaN
# 2                       NaN                                   NaN
# 3                       NaN                                   NaN
# 4                       NaN                                   NaN
# ..                      ...                                   ...
# 499         Bottom Brackets  a9e54089-8a1e-4cf5-8646-e3801f685934
# 500         Bottom Brackets  a9e54089-8a1e-4cf5-8646-e3801f685934
# 501              Road Bikes  000310c0-bcc8-42c4-b0c3-45ae611af06b
# 502              Road Bikes  000310c0-bcc8-42c4-b0c3-45ae611af06b
# 503              Road Bikes  000310c0-bcc8-42c4-b0c3-45ae611af06b
#
#                modifieddate_y productcategoryname  \
# 0                         NaT                 NaN
# 1                         NaT                 NaN
# 2                         NaT                 NaN
# 3                         NaT                 NaN
# 4                         NaT                 NaN
# ..                        ...                 ...
# 499 2008-04-30 00:00:00+00:00          Components
# 500 2008-04-30 00:00:00+00:00          Components
# 501 2008-04-30 00:00:00+00:00               Bikes
# 502 2008-04-30 00:00:00+00:00               Bikes
# 503 2008-04-30 00:00:00+00:00               Bikes
#
#                                   rowguid              modifieddate
# 0                                     NaN                       NaT
# 1                                     NaN                       NaT
# 2                                     NaN                       NaT
# 3                                     NaN                       NaT
# 4                                     NaN                       NaT
# ..                                    ...                       ...
# 499  c657828d-d808-4aba-91a3-af2ce02300e9 2008-04-30 00:00:00+00:00
# 500  c657828d-d808-4aba-91a3-af2ce02300e9 2008-04-30 00:00:00+00:00
# 501  cfbda25c-df71-47a7-b81b-64ee161aa37c 2008-04-30 00:00:00+00:00
# 502  cfbda25c-df71-47a7-b81b-64ee161aa37c 2008-04-30 00:00:00+00:00
# 503  cfbda25c-df71-47a7-b81b-64ee161aa37c 2008-04-30 00:00:00+00:00
#
# [504 rows x 32 columns]

# %%
dimproduct = dimproduct[[
    "productid",
    "name",
    "color",
    "size",
    "productsubcategoryid",
    "productsubcategoryname",
    "productcategoryid",
    "productcategoryname",
    "listprice"
]].drop_duplicates()

# %%
#DIMENSION PRODUCTO
dimproduct
# Out:
#      productid                   name  color  size  productsubcategoryid  \
# 0            1        Adjustable Race   None  None                   NaN
# 1            2           Bearing Ball   None  None                   NaN
# 2            3        BB Ball Bearing   None  None                   NaN
# 3            4  Headset Ball Bearings   None  None                   NaN
# 4          316                  Blade   None  None                   NaN
# ..         ...                    ...    ...   ...                   ...
# 499        995      ML Bottom Bracket   None  None                   5.0
# 500        996      HL Bottom Bracket   None  None                   5.0
# 501        997     Road-750 Black, 44  Black    44                   2.0
# 502        998     Road-750 Black, 48  Black    48                   2.0
# 503        999     Road-750 Black, 52  Black    52                   2.0
#
#     productsubcategoryname  productcategoryid productcategoryname  listprice
# 0                      NaN                NaN                 NaN       0.00
# 1                      NaN                NaN                 NaN       0.00
# 2                      NaN                NaN                 NaN       0.00
# 3                      NaN                NaN                 NaN       0.00
# 4                      NaN                NaN                 NaN       0.00
# ..                     ...                ...                 ...        ...
# 499        Bottom Brackets                2.0          Components     101.24
# 500        Bottom Brackets                2.0          Components     121.49
# 501             Road Bikes                1.0               Bikes     539.99
# 502             Road Bikes                1.0               Bikes     539.99
# 503             Road Bikes                1.0               Bikes     539.99
#
# [504 rows x 9 columns]

# %%
#DIMENSION PROMOCION
dimpromotion = (
    specialoffer
    .merge(specialofferproduct, on="specialofferid", how="left")
)[[
    "specialofferid",
    "description",
    "discountpct",
    "startdate",
    "enddate",
    "productid",
    "category",
    "type",
    "minqty",
    "maxqty"
]].drop_duplicates()

# %%
dimpromotion
# Out:
#      specialofferid                         description  discountpct  \
# 0                 1                         No Discount          0.0
# 1                 1                         No Discount          0.0
# 2                 1                         No Discount          0.0
# 3                 1                         No Discount          0.0
# 4                 1                         No Discount          0.0
# ..              ...                                 ...          ...
# 534              16  Mountain-500 Silver Clearance Sale          0.4
# 535              16  Mountain-500 Silver Clearance Sale          0.4
# 536              16  Mountain-500 Silver Clearance Sale          0.4
# 537              16  Mountain-500 Silver Clearance Sale          0.4
# 538              16  Mountain-500 Silver Clearance Sale          0.4
#
#                     startdate                   enddate  productid  \
# 0   2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00      680.0
# 1   2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00      706.0
# 2   2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00      707.0
# 3   2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00      708.0
# 4   2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00      709.0
# ..                        ...                       ...        ...
# 534 2014-03-31 00:00:00+00:00 2014-05-30 00:00:00+00:00      984.0
# 535 2014-03-31 00:00:00+00:00 2014-05-30 00:00:00+00:00      985.0
# 536 2014-03-31 00:00:00+00:00 2014-05-30 00:00:00+00:00      986.0
# 537 2014-03-31 00:00:00+00:00 2014-05-30 00:00:00+00:00      987.0
# 538 2014-03-31 00:00:00+00:00 2014-05-30 00:00:00+00:00      988.0
#
#         category                  type  minqty  maxqty
# 0    No Discount           No Discount       0     NaN
# 1    No Discount           No Discount       0     NaN
# 2    No Discount           No Discount       0     NaN
# 3    No Discount           No Discount       0     NaN
# 4    No Discount           No Discount       0     NaN
# ..           ...                   ...     ...     ...
# 534     Reseller  Discontinued Product       0     NaN
# 535     Reseller  Discontinued Product       0     NaN
# 536     Reseller  Discontinued Product       0     NaN
# 537     Reseller  Discontinued Product       0     NaN
# 538     Reseller  Discontinued Product       0     NaN
#
# [539 rows x 10 columns]

# %%
#DIM SALES TERRITORY
dimsalesterritory = salesterritory[[
    "territoryid",
    "name",
    "countryregioncode",
    "group"
]].drop_duplicates()
dimsalesterritory
# Out:
#    territoryid            name countryregioncode          group
# 0            1       Northwest                US  North America
# 1            2       Northeast                US  North America
# 2            3         Central                US  North America
# 3            4       Southwest                US  North America
# 4            5       Southeast                US  North America
# 5            6          Canada                CA  North America
# 6            7          France                FR         Europe
# 7            8         Germany                DE         Europe
# 8            9       Australia                AU        Pacific
# 9           10  United Kingdom                GB         Europe

# %%
#HECHO VENTAS POR INTERNET
internet_sales = salesorderheader[salesorderheader["onlineorderflag"] == True]

# %%
factInternet = (internet_sales.merge(salesorderdetail, on="salesorderid"))
factInternet
# Out:
#        salesorderid  revisionnumber                 orderdate  \
# 0             43697               8 2011-05-31 00:00:00+00:00
# 1             43698               8 2011-05-31 00:00:00+00:00
# 2             43699               8 2011-05-31 00:00:00+00:00
# 3             43700               8 2011-05-31 00:00:00+00:00
# 4             43701               8 2011-05-31 00:00:00+00:00
# ...             ...             ...                       ...
# 60393         75122               8 2014-06-30 00:00:00+00:00
# 60394         75122               8 2014-06-30 00:00:00+00:00
# 60395         75123               8 2014-06-30 00:00:00+00:00
# 60396         75123               8 2014-06-30 00:00:00+00:00
# 60397         75123               8 2014-06-30 00:00:00+00:00
#
#                         duedate                  shipdate  status  \
# 0     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 1     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 2     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 3     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 4     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# ...                         ...                       ...     ...
# 60393 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 60394 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 60395 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 60396 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 60397 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
#
#        onlineorderflag salesordernumber purchaseordernumber   accountnumber  \
# 0                 True          SO43697                None  10-4030-021768
# 1                 True          SO43698                None  10-4030-028389
# 2                 True          SO43699                None  10-4030-025863
# 3                 True          SO43700                None  10-4030-014501
# 4                 True          SO43701                None  10-4030-011003
# ...                ...              ...                 ...             ...
# 60393             True          SO75122                None  10-4030-015868
# 60394             True          SO75122                None  10-4030-015868
# 60395             True          SO75123                None  10-4030-018759
# 60396             True          SO75123                None  10-4030-018759
# 60397             True          SO75123                None  10-4030-018759
#
#        ...  salesorderdetailid  carriertrackingnumber  orderqty  productid  \
# 0      ...                 353                   None         1        749
# 1      ...                 354                   None         1        773
# 2      ...                 355                   None         1        773
# 3      ...                 356                   None         1        767
# 4      ...                 357                   None         1        773
# ...    ...                 ...                    ...       ...        ...
# 60393  ...              121313                   None         1        878
# 60394  ...              121314                   None         1        712
# 60395  ...              121315                   None         1        878
# 60396  ...              121316                   None         1        879
# 60397  ...              121317                   None         1        712
#
#        specialofferid  unitprice  unitpricediscount  linetotal  \
# 0                   1  3578.2700                0.0  3578.2700
# 1                   1  3399.9900                0.0  3399.9900
# 2                   1  3399.9900                0.0  3399.9900
# 3                   1   699.0982                0.0   699.0982
# 4                   1  3399.9900                0.0  3399.9900
# ...               ...        ...                ...        ...
# 60393               1    21.9800                0.0    21.9800
# 60394               1     8.9900                0.0     8.9900
# 60395               1    21.9800                0.0    21.9800
# 60396               1   159.0000                0.0   159.0000
# 60397               1     8.9900                0.0     8.9900
#
#                                   rowguid_y            modifieddate_y
# 0      ca258bf8-1f52-4ae6-8e8f-5439ae0c9509 2011-05-31 00:00:00+00:00
# 1      a2d7730f-d2d0-4c47-8f36-fbd316680cef 2011-05-31 00:00:00+00:00
# 2      2543c7bf-679b-47f3-a04f-eb5da849ef32 2011-05-31 00:00:00+00:00
# 3      6d43204a-dba1-4013-bc4d-0273baa703c9 2011-05-31 00:00:00+00:00
# 4      5ff3b05f-57f0-4885-8e7b-64c4ad71aeb5 2011-05-31 00:00:00+00:00
# ...                                     ...                       ...
# 60393  8cad6675-18cc-4f47-8287-97b41a8ee47d 2014-06-30 00:00:00+00:00
# 60394  84f1c363-1c50-4442-be16-541c59b6e12c 2014-06-30 00:00:00+00:00
# 60395  c18b6476-429f-4bb1-828e-2be5f82a0a51 2014-06-30 00:00:00+00:00
# 60396  75a89c6a-c60a-47ea-8a52-b52a9c435b64 2014-06-30 00:00:00+00:00
# 60397  73646d26-0461-450d-8019-2c6c858619ca 2014-06-30 00:00:00+00:00
#
# [60398 rows x 36 columns]

# %%
factInternet = factInternet.merge(dimproduct, on="productid", how="left")
factInternet
# Out:
#        salesorderid  revisionnumber                 orderdate  \
# 0             43697               8 2011-05-31 00:00:00+00:00
# 1             43698               8 2011-05-31 00:00:00+00:00
# 2             43699               8 2011-05-31 00:00:00+00:00
# 3             43700               8 2011-05-31 00:00:00+00:00
# 4             43701               8 2011-05-31 00:00:00+00:00
# ...             ...             ...                       ...
# 60393         75122               8 2014-06-30 00:00:00+00:00
# 60394         75122               8 2014-06-30 00:00:00+00:00
# 60395         75123               8 2014-06-30 00:00:00+00:00
# 60396         75123               8 2014-06-30 00:00:00+00:00
# 60397         75123               8 2014-06-30 00:00:00+00:00
#
#                         duedate                  shipdate  status  \
# 0     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 1     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 2     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 3     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 4     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# ...                         ...                       ...     ...
# 60393 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 60394 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 60395 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 60396 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 60397 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
#
#        onlineorderflag salesordernumber purchaseordernumber   accountnumber  \
# 0                 True          SO43697                None  10-4030-021768
# 1                 True          SO43698                None  10-4030-028389
# 2                 True          SO43699                None  10-4030-025863
# 3                 True          SO43700                None  10-4030-014501
# 4                 True          SO43701                None  10-4030-011003
# ...                ...              ...                 ...             ...
# 60393             True          SO75122                None  10-4030-015868
# 60394             True          SO75122                None  10-4030-015868
# 60395             True          SO75123                None  10-4030-018759
# 60396             True          SO75123                None  10-4030-018759
# 60397             True          SO75123                None  10-4030-018759
#
#        ...                             rowguid_y            modifieddate_y  \
# 0      ...  ca258bf8-1f52-4ae6-8e8f-5439ae0c9509 2011-05-31 00:00:00+00:00
# 1      ...  a2d7730f-d2d0-4c47-8f36-fbd316680cef 2011-05-31 00:00:00+00:00
# 2      ...  2543c7bf-679b-47f3-a04f-eb5da849ef32 2011-05-31 00:00:00+00:00
# 3      ...  6d43204a-dba1-4013-bc4d-0273baa703c9 2011-05-31 00:00:00+00:00
# 4      ...  5ff3b05f-57f0-4885-8e7b-64c4ad71aeb5 2011-05-31 00:00:00+00:00
# ...    ...                                   ...                       ...
# 60393  ...  8cad6675-18cc-4f47-8287-97b41a8ee47d 2014-06-30 00:00:00+00:00
# 60394  ...  84f1c363-1c50-4442-be16-541c59b6e12c 2014-06-30 00:00:00+00:00
# 60395  ...  c18b6476-429f-4bb1-828e-2be5f82a0a51 2014-06-30 00:00:00+00:00
# 60396  ...  75a89c6a-c60a-47ea-8a52-b52a9c435b64 2014-06-30 00:00:00+00:00
# 60397  ...  73646d26-0461-450d-8019-2c6c858619ca 2014-06-30 00:00:00+00:00
#
#                           name   color  size  productsubcategoryid  \
# 0             Road-150 Red, 62     Red    62                   2.0
# 1      Mountain-100 Silver, 44  Silver    44                   1.0
# 2      Mountain-100 Silver, 44  Silver    44                   1.0
# 3           Road-650 Black, 62   Black    62                   2.0
# 4      Mountain-100 Silver, 44  Silver    44                   1.0
# ...                        ...     ...   ...                   ...
# 60393    Fender Set - Mountain    None  None                  30.0
# 60394             AWC Logo Cap   Multi  None                  19.0
# 60395    Fender Set - Mountain    None  None                  30.0
# 60396   All-Purpose Bike Stand    None  None                  27.0
# 60397             AWC Logo Cap   Multi  None                  19.0
#
#        productsubcategoryname productcategoryid  productcategoryname  \
# 0                  Road Bikes               1.0                Bikes
# 1              Mountain Bikes               1.0                Bikes
# 2              Mountain Bikes               1.0                Bikes
# 3                  Road Bikes               1.0                Bikes
# 4              Mountain Bikes               1.0                Bikes
# ...                       ...               ...                  ...
# 60393                 Fenders               4.0          Accessories
# 60394                    Caps               3.0             Clothing
# 60395                 Fenders               4.0          Accessories
# 60396             Bike Stands               4.0          Accessories
# 60397                    Caps               3.0             Clothing
#
#        listprice
# 0        3578.27
# 1        3399.99
# 2        3399.99
# 3         782.99
# 4        3399.99
# ...          ...
# 60393      21.98
# 60394       8.99
# 60395      21.98
# 60396     159.00
# 60397       8.99
#
# [60398 rows x 44 columns]

# %%
mergedimecustomer = dimcustomer
mergedimecustomer = mergedimecustomer.rename(columns={'territoryid': 'territoryidCustomer'})
factInternet = factInternet.merge(mergedimecustomer, on="customerid", how="left")
factInternet
# Out:
#        salesorderid  revisionnumber                 orderdate  \
# 0             43697               8 2011-05-31 00:00:00+00:00
# 1             43698               8 2011-05-31 00:00:00+00:00
# 2             43699               8 2011-05-31 00:00:00+00:00
# 3             43700               8 2011-05-31 00:00:00+00:00
# 4             43701               8 2011-05-31 00:00:00+00:00
# ...             ...             ...                       ...
# 60454         75122               8 2014-06-30 00:00:00+00:00
# 60455         75122               8 2014-06-30 00:00:00+00:00
# 60456         75123               8 2014-06-30 00:00:00+00:00
# 60457         75123               8 2014-06-30 00:00:00+00:00
# 60458         75123               8 2014-06-30 00:00:00+00:00
#
#                         duedate                  shipdate  status  \
# 0     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 1     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 2     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 3     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 4     2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# ...                         ...                       ...     ...
# 60454 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 60455 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 60456 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 60457 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 60458 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
#
#        onlineorderflag salesordernumber purchaseordernumber   accountnumber  \
# 0                 True          SO43697                None  10-4030-021768
# 1                 True          SO43698                None  10-4030-028389
# 2                 True          SO43699                None  10-4030-025863
# 3                 True          SO43700                None  10-4030-014501
# 4                 True          SO43701                None  10-4030-011003
# ...                ...              ...                 ...             ...
# 60454             True          SO75122                None  10-4030-015868
# 60455             True          SO75122                None  10-4030-015868
# 60456             True          SO75123                None  10-4030-018759
# 60457             True          SO75123                None  10-4030-018759
# 60458             True          SO75123                None  10-4030-018759
#
#        ...  productcategoryid  productcategoryname  listprice  firstname  \
# 0      ...                1.0                Bikes    3578.27       Cole
# 1      ...                1.0                Bikes    3399.99    Rachael
# 2      ...                1.0                Bikes    3399.99     Sydney
# 3      ...                1.0                Bikes     782.99      Ruben
# 4      ...                1.0                Bikes    3399.99    Christy
# ...    ...                ...                  ...        ...        ...
# 60454  ...                4.0          Accessories      21.98      Caleb
# 60455  ...                3.0             Clothing       8.99      Caleb
# 60456  ...                4.0          Accessories      21.98      Devin
# 60457  ...                4.0          Accessories     159.00      Devin
# 60458  ...                3.0             Clothing       8.99      Devin
#
#        lastname          addressline1           city stateprovinceid  \
# 0        Watson      601 Asilomar Dr.      Metchosin               7
# 1      Martinez    14, avenue du Port         Pantin             179
# 2        Wright   4193 E. 28th Street        Lebanon              58
# 3        Prasad     249 Alexander Pl.  Beverly Hills               9
# 4           Zhu      1825 Village Pl.     North Ryde              50
# ...         ...                   ...            ...             ...
# 60454       Lal     4037 San View Way          Sooke               7
# 60455       Lal     4037 San View Way          Sooke               7
# 60456  Phillips  2742 Cincerto Circle          Sooke               7
# 60457  Phillips  2742 Cincerto Circle          Sooke               7
# 60458  Phillips  2742 Cincerto Circle          Sooke               7
#
#        countryregioncode  territoryidCustomer
# 0                     CA                    6
# 1                     FR                    7
# 2                     US                    1
# 3                     US                    4
# 4                     AU                    9
# ...                  ...                  ...
# 60454                 CA                    6
# 60455                 CA                    6
# 60456                 CA                    6
# 60457                 CA                    6
# 60458                 CA                    6
#
# [60459 rows x 51 columns]

# %%
factInternet = factInternet.merge(dimpromotion, on="productid", how="left")
factInternet
# Out:
#         salesorderid  revisionnumber                 orderdate  \
# 0              43697               8 2011-05-31 00:00:00+00:00
# 1              43698               8 2011-05-31 00:00:00+00:00
# 2              43698               8 2011-05-31 00:00:00+00:00
# 3              43698               8 2011-05-31 00:00:00+00:00
# 4              43698               8 2011-05-31 00:00:00+00:00
# ...              ...             ...                       ...
# 478845         75123               8 2014-06-30 00:00:00+00:00
# 478846         75123               8 2014-06-30 00:00:00+00:00
# 478847         75123               8 2014-06-30 00:00:00+00:00
# 478848         75123               8 2014-06-30 00:00:00+00:00
# 478849         75123               8 2014-06-30 00:00:00+00:00
#
#                          duedate                  shipdate  status  \
# 0      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 1      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 2      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 3      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 4      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# ...                          ...                       ...     ...
# 478845 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 478846 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 478847 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 478848 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 478849 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
#
#         onlineorderflag salesordernumber purchaseordernumber   accountnumber  \
# 0                  True          SO43697                None  10-4030-021768
# 1                  True          SO43698                None  10-4030-028389
# 2                  True          SO43698                None  10-4030-028389
# 3                  True          SO43698                None  10-4030-028389
# 4                  True          SO43698                None  10-4030-028389
# ...                 ...              ...                 ...             ...
# 478845             True          SO75123                None  10-4030-018759
# 478846             True          SO75123                None  10-4030-018759
# 478847             True          SO75123                None  10-4030-018759
# 478848             True          SO75123                None  10-4030-018759
# 478849             True          SO75123                None  10-4030-018759
#
#         ...  maxqty_x  specialofferid                description_y  \
# 0       ...       NaN               1                  No Discount
# 1       ...       NaN               1                  No Discount
# 2       ...       NaN               2     Volume Discount 11 to 14
# 3       ...       NaN               7  Mountain-100 Clearance Sale
# 4       ...      14.0               1                  No Discount
# ...     ...       ...             ...                          ...
# 478845  ...      24.0               4     Volume Discount 25 to 40
# 478846  ...      40.0               1                  No Discount
# 478847  ...      40.0               2     Volume Discount 11 to 14
# 478848  ...      40.0               3     Volume Discount 15 to 24
# 478849  ...      40.0               4     Volume Discount 25 to 40
#
#         discountpct_y               startdate_y                 enddate_y  \
# 0                0.00 2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00
# 1                0.00 2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00
# 2                0.02 2011-05-31 00:00:00+00:00 2014-05-30 00:00:00+00:00
# 3                0.35 2012-04-13 00:00:00+00:00 2012-05-29 00:00:00+00:00
# 4                0.00 2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00
# ...               ...                       ...                       ...
# 478845           0.10 2011-05-31 00:00:00+00:00 2014-05-30 00:00:00+00:00
# 478846           0.00 2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00
# 478847           0.02 2011-05-31 00:00:00+00:00 2014-05-30 00:00:00+00:00
# 478848           0.05 2011-05-31 00:00:00+00:00 2014-05-30 00:00:00+00:00
# 478849           0.10 2011-05-31 00:00:00+00:00 2014-05-30 00:00:00+00:00
#
#          category_y                type_y  minqty_y  maxqty_y
# 0       No Discount           No Discount         0       NaN
# 1       No Discount           No Discount         0       NaN
# 2          Reseller       Volume Discount        11      14.0
# 3          Reseller  Discontinued Product         0       NaN
# 4       No Discount           No Discount         0       NaN
# ...             ...                   ...       ...       ...
# 478845     Reseller       Volume Discount        25      40.0
# 478846  No Discount           No Discount         0       NaN
# 478847     Reseller       Volume Discount        11      14.0
# 478848     Reseller       Volume Discount        15      24.0
# 478849     Reseller       Volume Discount        25      40.0
#
# [478850 rows x 69 columns]

# %%
factInternet = factInternet.merge(dimsalesterritory, on="territoryid", how="left")
factInternet
# Out:
#         salesorderid  revisionnumber                 orderdate  \
# 0              43697               8 2011-05-31 00:00:00+00:00
# 1              43698               8 2011-05-31 00:00:00+00:00
# 2              43698               8 2011-05-31 00:00:00+00:00
# 3              43698               8 2011-05-31 00:00:00+00:00
# 4              43698               8 2011-05-31 00:00:00+00:00
# ...              ...             ...                       ...
# 478845         75123               8 2014-06-30 00:00:00+00:00
# 478846         75123               8 2014-06-30 00:00:00+00:00
# 478847         75123               8 2014-06-30 00:00:00+00:00
# 478848         75123               8 2014-06-30 00:00:00+00:00
# 478849         75123               8 2014-06-30 00:00:00+00:00
#
#                          duedate                  shipdate  status  \
# 0      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 1      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 2      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 3      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 4      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# ...                          ...                       ...     ...
# 478845 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 478846 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 478847 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 478848 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
# 478849 2014-07-12 00:00:00+00:00 2014-07-07 00:00:00+00:00       5
#
#         onlineorderflag salesordernumber purchaseordernumber   accountnumber  \
# 0                  True          SO43697                None  10-4030-021768
# 1                  True          SO43698                None  10-4030-028389
# 2                  True          SO43698                None  10-4030-028389
# 3                  True          SO43698                None  10-4030-028389
# 4                  True          SO43698                None  10-4030-028389
# ...                 ...              ...                 ...             ...
# 478845             True          SO75123                None  10-4030-018759
# 478846             True          SO75123                None  10-4030-018759
# 478847             True          SO75123                None  10-4030-018759
# 478848             True          SO75123                None  10-4030-018759
# 478849             True          SO75123                None  10-4030-018759
#
#         ...  discountpct_y               startdate_y  \
# 0       ...           0.00 2011-05-01 00:00:00+00:00
# 1       ...           0.00 2011-05-01 00:00:00+00:00
# 2       ...           0.02 2011-05-31 00:00:00+00:00
# 3       ...           0.35 2012-04-13 00:00:00+00:00
# 4       ...           0.00 2011-05-01 00:00:00+00:00
# ...     ...            ...                       ...
# 478845  ...           0.10 2011-05-31 00:00:00+00:00
# 478846  ...           0.00 2011-05-01 00:00:00+00:00
# 478847  ...           0.02 2011-05-31 00:00:00+00:00
# 478848  ...           0.05 2011-05-31 00:00:00+00:00
# 478849  ...           0.10 2011-05-31 00:00:00+00:00
#
#                        enddate_y   category_y                type_y  minqty_y  \
# 0      2014-11-30 00:00:00+00:00  No Discount           No Discount         0
# 1      2014-11-30 00:00:00+00:00  No Discount           No Discount         0
# 2      2014-05-30 00:00:00+00:00     Reseller       Volume Discount        11
# 3      2012-05-29 00:00:00+00:00     Reseller  Discontinued Product         0
# 4      2014-11-30 00:00:00+00:00  No Discount           No Discount         0
# ...                          ...          ...                   ...       ...
# 478845 2014-05-30 00:00:00+00:00     Reseller       Volume Discount        25
# 478846 2014-11-30 00:00:00+00:00  No Discount           No Discount         0
# 478847 2014-05-30 00:00:00+00:00     Reseller       Volume Discount        11
# 478848 2014-05-30 00:00:00+00:00     Reseller       Volume Discount        15
# 478849 2014-05-30 00:00:00+00:00     Reseller       Volume Discount        25
#
#         maxqty_y  name_y  countryregioncode_y          group
# 0            NaN  Canada                   CA  North America
# 1            NaN  France                   FR         Europe
# 2           14.0  France                   FR         Europe
# 3            NaN  France                   FR         Europe
# 4            NaN  France                   FR         Europe
# ...          ...     ...                  ...            ...
# 478845      40.0  Canada                   CA  North America
# 478846       NaN  Canada                   CA  North America
# 478847      14.0  Canada                   CA  North America
# 478848      24.0  Canada                   CA  North America
# 478849      40.0  Canada                   CA  North America
#
# [478850 rows x 72 columns]

# %%
# Generar claves de fecha
factInternet["orderdatekey"] = pd.to_datetime(factInternet["orderdate"]).dt.strftime("%Y%m%d").astype(int)
factInternet["duedatekey"] = pd.to_datetime(factInternet["duedate"]).dt.strftime("%Y%m%d").astype(int)
factInternet["shipdatekey"] = pd.to_datetime(factInternet["shipdate"]).dt.strftime("%Y%m%d").astype(int)

# %%
factInternet = factInternet[[
    "salesorderid",
    "productid",
    "customerid",
    "territoryid",
    "orderqty",
    "unitprice",
    "unitpricediscount",
    "freight",
    "taxamt",
    "totaldue",
    "orderdatekey",
    "duedatekey",
    "shipdatekey"
]]
factInternet
# Out:
#         salesorderid  productid  customerid  territoryid  orderqty  unitprice  \
# 0              43697        749       21768            6         1    3578.27
# 1              43698        773       28389            7         1    3399.99
# 2              43698        773       28389            7         1    3399.99
# 3              43698        773       28389            7         1    3399.99
# 4              43698        773       28389            7         1    3399.99
# ...              ...        ...         ...          ...       ...        ...
# 478845         75123        712       18759            6         1       8.99
# 478846         75123        712       18759            6         1       8.99
# 478847         75123        712       18759            6         1       8.99
# 478848         75123        712       18759            6         1       8.99
# 478849         75123        712       18759            6         1       8.99
#
#         unitpricediscount  freight    taxamt   totaldue  orderdatekey  \
# 0                     0.0  89.4568  286.2616  3953.9883      20110531
# 1                     0.0  84.9998  271.9992  3756.9890      20110531
# 2                     0.0  84.9998  271.9992  3756.9890      20110531
# 3                     0.0  84.9998  271.9992  3756.9890      20110531
# 4                     0.0  84.9998  271.9992  3756.9890      20110531
# ...                   ...      ...       ...        ...           ...
# 478845                0.0   4.7493   15.1976   209.9169      20140630
# 478846                0.0   4.7493   15.1976   209.9169      20140630
# 478847                0.0   4.7493   15.1976   209.9169      20140630
# 478848                0.0   4.7493   15.1976   209.9169      20140630
# 478849                0.0   4.7493   15.1976   209.9169      20140630
#
#         duedatekey  shipdatekey
# 0         20110612     20110607
# 1         20110612     20110607
# 2         20110612     20110607
# 3         20110612     20110607
# 4         20110612     20110607
# ...            ...          ...
# 478845    20140712     20140707
# 478846    20140712     20140707
# 478847    20140712     20140707
# 478848    20140712     20140707
# 478849    20140712     20140707
#
# [478850 rows x 13 columns]

# %%
#HECHO VENTAS POR REVENDEDORES  &(salesorderheader["storeid"].notnull())
customerMergeRevendedores = customer
salespersonCopiaTerritory = salesperson[['territoryid', 'businessentityid']]
customerMergeRevendedores = customerMergeRevendedores[['customerid','storeid']]
reseller_sales = salesorderheader[(salesorderheader["onlineorderflag"] == False)]
reseller_sales = reseller_sales.merge(customerMergeRevendedores, on="customerid", how="left")
reseller_sales = reseller_sales.merge(salespersonCopiaTerritory, on="territoryid", how="left")

# %%
reseller_sales = reseller_sales[(reseller_sales["storeid"].notnull())]
reseller_sales
# Out:
#       salesorderid  revisionnumber                 orderdate  \
# 0            43659               8 2011-05-31 00:00:00+00:00
# 1            43660               8 2011-05-31 00:00:00+00:00
# 2            43661               8 2011-05-31 00:00:00+00:00
# 3            43661               8 2011-05-31 00:00:00+00:00
# 4            43662               8 2011-05-31 00:00:00+00:00
# ...            ...             ...                       ...
# 6316         71949               8 2014-05-01 00:00:00+00:00
# 6317         71950               8 2014-05-01 00:00:00+00:00
# 6318         71951               8 2014-05-01 00:00:00+00:00
# 6319         71952               8 2014-05-01 00:00:00+00:00
# 6320         71952               8 2014-05-01 00:00:00+00:00
#
#                        duedate                  shipdate  status  \
# 0    2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 1    2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 2    2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 3    2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 4    2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# ...                        ...                       ...     ...
# 6316 2014-05-13 00:00:00+00:00 2014-05-08 00:00:00+00:00       5
# 6317 2014-05-13 00:00:00+00:00 2014-05-08 00:00:00+00:00       5
# 6318 2014-05-13 00:00:00+00:00 2014-05-08 00:00:00+00:00       5
# 6319 2014-05-13 00:00:00+00:00 2014-05-08 00:00:00+00:00       5
# 6320 2014-05-13 00:00:00+00:00 2014-05-08 00:00:00+00:00       5
#
#       onlineorderflag salesordernumber purchaseordernumber   accountnumber  \
# 0               False          SO43659         PO522145787  10-4020-000676
# 1               False          SO43660       PO18850127500  10-4020-000117
# 2               False          SO43661       PO18473189620  10-4020-000442
# 3               False          SO43661       PO18473189620  10-4020-000442
# 4               False          SO43662       PO18444174044  10-4020-000227
# ...               ...              ...                 ...             ...
# 6316            False          SO71949        PO9483195097  10-4020-000054
# 6317            False          SO71950        PO9744193484  10-4020-000098
# 6318            False          SO71951        PO9106170008  10-4020-000602
# 6319            False          SO71952        PO9715163911  10-4020-000490
# 6320            False          SO71952        PO9715163911  10-4020-000490
#
#       ...  currencyrateid    subtotal     taxamt    freight    totaldue  \
# 0     ...             NaN  20565.6210  1971.5149   616.0984  23153.2340
# 1     ...             NaN   1294.2529   124.2483    38.8276   1457.3289
# 2     ...             4.0  32726.4790  3153.7695   985.5530  36865.8000
# 3     ...             4.0  32726.4790  3153.7695   985.5530  36865.8000
# 4     ...             4.0  28832.5300  2775.1646   867.2389  32474.9320
# ...   ...             ...         ...        ...        ...         ...
# 6316  ...             NaN  34123.6680  3253.9468  1016.8583  38394.4730
# 6317  ...             NaN   3131.9340   297.1382    92.8557   3521.9280
# 6318  ...             NaN   1502.9760   143.1099    44.7218   1690.8077
# 6319  ...             NaN  67059.6300  6573.0030  2054.0635  75686.7000
# 6320  ...             NaN  67059.6300  6573.0030  2054.0635  75686.7000
#
#       comment                               rowguid              modifieddate  \
# 0        None  79b65321-39ca-4115-9cba-8fe0903e12e6 2011-06-07 00:00:00+00:00
# 1        None  738dc42d-d03b-48a1-9822-f95a67ea7389 2011-06-07 00:00:00+00:00
# 2        None  d91b9131-18a4-4a11-bc3a-90b6f53e9d74 2011-06-07 00:00:00+00:00
# 3        None  d91b9131-18a4-4a11-bc3a-90b6f53e9d74 2011-06-07 00:00:00+00:00
# 4        None  4a1ecfc0-cc3a-4740-b028-1c50bb48711c 2011-06-07 00:00:00+00:00
# ...       ...                                   ...                       ...
# 6316     None  0ffd145d-43b3-4a8d-b2e9-2e52e570820f 2014-05-08 00:00:00+00:00
# 6317     None  bfe09bc4-a7db-48cd-841e-572715972a20 2014-05-08 00:00:00+00:00
# 6318     None  2c020885-ad87-4563-a7ab-6e9595a75858 2014-05-08 00:00:00+00:00
# 6319     None  4b974418-cb6b-4887-8a40-e08cc5054d32 2014-05-08 00:00:00+00:00
# 6320     None  4b974418-cb6b-4887-8a40-e08cc5054d32 2014-05-08 00:00:00+00:00
#
#       storeid  businessentityid
# 0      1046.0               279
# 1       722.0               279
# 2       852.0               278
# 3       852.0               282
# 4      1418.0               278
# ...       ...               ...
# 6316   1356.0               275
# 6317    734.0               279
# 6318    654.0               279
# 6319   1836.0               276
# 6320   1836.0               281
#
# [6321 rows x 28 columns]

# %%
dimemployee = dimemployee.rename(columns={'territoryid': 'territoryidDimEmployee'})

factReseller = (
    reseller_sales
    .merge(salesorderdetail, on="salesorderid")
    .merge(dimproduct, on="productid", how="left")
    .merge(dimemployee, left_on="businessentityid", right_on="employeekey", how="left")
    .merge(dimreseller, on="storeid", how="left")
    .merge(dimpromotion, on="productid", how="left")
    .merge(dimsalesterritory, on="territoryid", how="left")
)
factReseller
# Out:
#         salesorderid  revisionnumber                 orderdate  \
# 0              43659               8 2011-05-31 00:00:00+00:00
# 1              43659               8 2011-05-31 00:00:00+00:00
# 2              43659               8 2011-05-31 00:00:00+00:00
# 3              43659               8 2011-05-31 00:00:00+00:00
# 4              43659               8 2011-05-31 00:00:00+00:00
# ...              ...             ...                       ...
# 499409         71952               8 2014-05-01 00:00:00+00:00
# 499410         71952               8 2014-05-01 00:00:00+00:00
# 499411         71952               8 2014-05-01 00:00:00+00:00
# 499412         71952               8 2014-05-01 00:00:00+00:00
# 499413         71952               8 2014-05-01 00:00:00+00:00
#
#                          duedate                  shipdate  status  \
# 0      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 1      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 2      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 3      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# 4      2011-06-12 00:00:00+00:00 2011-06-07 00:00:00+00:00       5
# ...                          ...                       ...     ...
# 499409 2014-05-13 00:00:00+00:00 2014-05-08 00:00:00+00:00       5
# 499410 2014-05-13 00:00:00+00:00 2014-05-08 00:00:00+00:00       5
# 499411 2014-05-13 00:00:00+00:00 2014-05-08 00:00:00+00:00       5
# 499412 2014-05-13 00:00:00+00:00 2014-05-08 00:00:00+00:00       5
# 499413 2014-05-13 00:00:00+00:00 2014-05-08 00:00:00+00:00       5
#
#         onlineorderflag salesordernumber purchaseordernumber   accountnumber  \
# 0                 False          SO43659         PO522145787  10-4020-000676
# 1                 False          SO43659         PO522145787  10-4020-000676
# 2                 False          SO43659         PO522145787  10-4020-000676
# 3                 False          SO43659         PO522145787  10-4020-000676
# 4                 False          SO43659         PO522145787  10-4020-000676
# ...                 ...              ...                 ...             ...
# 499409            False          SO71952        PO9715163911  10-4020-000490
# 499410            False          SO71952        PO9715163911  10-4020-000490
# 499411            False          SO71952        PO9715163911  10-4020-000490
# 499412            False          SO71952        PO9715163911  10-4020-000490
# 499413            False          SO71952        PO9715163911  10-4020-000490
#
#         ...  discountpct                 startdate                   enddate  \
# 0       ...         0.00 2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00
# 1       ...         0.02 2011-05-31 00:00:00+00:00 2014-05-30 00:00:00+00:00
# 2       ...         0.35 2012-04-13 00:00:00+00:00 2012-05-29 00:00:00+00:00
# 3       ...         0.00 2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00
# 4       ...         0.02 2011-05-31 00:00:00+00:00 2014-05-30 00:00:00+00:00
# ...     ...          ...                       ...                       ...
# 499409  ...         0.00 2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00
# 499410  ...         0.00 2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00
# 499411  ...         0.40 2014-03-31 00:00:00+00:00 2014-05-30 00:00:00+00:00
# 499412  ...         0.00 2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00
# 499413  ...         0.40 2014-03-31 00:00:00+00:00 2014-05-30 00:00:00+00:00
#
#            category                  type  minqty  maxqty       name  \
# 0       No Discount           No Discount       0     NaN  Southeast
# 1          Reseller       Volume Discount      11    14.0  Southeast
# 2          Reseller  Discontinued Product       0     NaN  Southeast
# 3       No Discount           No Discount       0     NaN  Southeast
# 4          Reseller       Volume Discount      11    14.0  Southeast
# ...             ...                   ...     ...     ...        ...
# 499409  No Discount           No Discount       0     NaN  Southwest
# 499410  No Discount           No Discount       0     NaN  Southwest
# 499411     Reseller  Discontinued Product       0     NaN  Southwest
# 499412  No Discount           No Discount       0     NaN  Southwest
# 499413     Reseller  Discontinued Product       0     NaN  Southwest
#
#         countryregioncode          group
# 0                      US  North America
# 1                      US  North America
# 2                      US  North America
# 3                      US  North America
# 4                      US  North America
# ...                   ...            ...
# 499409                 US  North America
# 499410                 US  North America
# 499411                 US  North America
# 499412                 US  North America
# 499413                 US  North America
#
# [499414 rows x 70 columns]

# %%
factReseller["orderdatekey"] = pd.to_datetime(factReseller["orderdate"]).dt.strftime("%Y%m%d").astype(int)
factReseller["duedatekey"] = pd.to_datetime(factReseller["duedate"]).dt.strftime("%Y%m%d").astype(int)
factReseller["shipdatekey"] = pd.to_datetime(factReseller["shipdate"]).dt.strftime("%Y%m%d").astype(int)

# %%
factReseller = factReseller[[
    "salesorderid",
    "productid",
    "storeid",
    "employeekey",
    "territoryid",
    "orderqty",
    "unitprice",
    "unitpricediscount",
    "freight",
    "taxamt",
    "totaldue",
    "orderdatekey",
    "duedatekey",
    "shipdatekey"
]]
factReseller= factReseller.rename(columns={'employeekey':'businessentityid'})
factReseller
# Out:
#         salesorderid  productid  storeid  businessentityid  territoryid  \
# 0              43659        776   1046.0               279            5
# 1              43659        776   1046.0               279            5
# 2              43659        776   1046.0               279            5
# 3              43659        776   1046.0               279            5
# 4              43659        776   1046.0               279            5
# ...              ...        ...      ...               ...          ...
# 499409         71952        994   1836.0               281            4
# 499410         71952        985   1836.0               281            4
# 499411         71952        985   1836.0               281            4
# 499412         71952        985   1836.0               281            4
# 499413         71952        985   1836.0               281            4
#
#         orderqty  unitprice  unitpricediscount    freight     taxamt  \
# 0              1   2024.994                0.0   616.0984  1971.5149
# 1              1   2024.994                0.0   616.0984  1971.5149
# 2              1   2024.994                0.0   616.0984  1971.5149
# 3              1   2024.994                0.0   616.0984  1971.5149
# 4              1   2024.994                0.0   616.0984  1971.5149
# ...          ...        ...                ...        ...        ...
# 499409         3     32.394                0.0  2054.0635  6573.0030
# 499410         3    112.998                0.4  2054.0635  6573.0030
# 499411         3    112.998                0.4  2054.0635  6573.0030
# 499412         3    112.998                0.4  2054.0635  6573.0030
# 499413         3    112.998                0.4  2054.0635  6573.0030
#
#          totaldue  orderdatekey  duedatekey  shipdatekey
# 0       23153.234      20110531    20110612     20110607
# 1       23153.234      20110531    20110612     20110607
# 2       23153.234      20110531    20110612     20110607
# 3       23153.234      20110531    20110612     20110607
# 4       23153.234      20110531    20110612     20110607
# ...           ...           ...         ...          ...
# 499409  75686.700      20140501    20140513     20140508
# 499410  75686.700      20140501    20140513     20140508
# 499411  75686.700      20140501    20140513     20140508
# 499412  75686.700      20140501    20140513     20140508
# 499413  75686.700      20140501    20140513     20140508
#
# [499414 rows x 14 columns]

# %%
reseller_sales['businessentityid']
# Out:
# 0       279
# 1       279
# 2       278
# 3       282
# 4       278
#        ...
# 6316    275
# 6317    279
# 6318    279
# 6319    276
# 6320    281
# Name: businessentityid, Length: 6321, dtype: int64
